# %%
import nltk  
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import numpy as np  
import random  
import string

import bs4 as bs #Beautiful soup library that is used for webscraping 
import urllib.request  #Reading in HTML data
import re #Regular Expression- Used for text processing like removing spaces, coverting uppercase words to lowercase words etc

# %%
raw_html = urllib.request.urlopen('https://www.bbc.com/news/world-us-canada-49942394')  
raw_html = raw_html.read()

article_html = bs.BeautifulSoup(raw_html, 'lxml')

article_paragraphs = article_html.find_all('p')

article_text = ''

for para in article_paragraphs:  
    article_text += para.text
print(article_text)
# Out:
# Share this withEmailFacebookMessengerMessengerTwitterPinterestWhatsAppLinkedInCopy this linkThese are external links and will open in a new windowUS Democratic lawmakers have demanded documents from the White House as part of their impeachment inquiry into President Donald Trump. The documents relate to a call between Mr Trump and Ukrainian President Volodymyr Zelensky on 25 July.  In the call, Mr Trump pushed Mr Zelensky to investigate his leading Democratic political rival, Joe Biden.The impeachment inquiry stems from the call, which was flagged up by a whistleblower in August.The whistleblower alleged that Mr Trump used a $400m military aid package to Ukraine, which had been suspended earlier in July, as leverage to persuade Mr Zelensky. The White House released the aid in September.Mr Trump has denied any wrongdoing, accusing his political opponents of a "witch hunt".But in a move to crank up the pressure on the president, the three House committees leading the investigation have
# ...

# %%
word_tokens = word_tokenize(lower_text) 
print(word_tokens)
# Out:
# ['share', 'this', 'withemailfacebookmessengermessengertwitterpinterestwhatsapplinkedincopy', 'this', 'linkthese', 'are', 'external', 'links', 'and', 'will', 'open', 'in', 'a', 'new', 'windowus', 'democratic', 'lawmakers', 'have', 'demanded', 'documents', 'from', 'the', 'white', 'house', 'as', 'part', 'of', 'their', 'impeachment', 'inquiry', 'into', 'president', 'donald', 'trump', '.', 'the', 'documents', 'relate', 'to', 'a', 'call', 'between', 'mr', 'trump', 'and', 'ukrainian', 'president', 'volodymyr', 'zelensky', 'on', '25', 'july', '.', 'in', 'the', 'call', ',', 'mr', 'trump', 'pushed', 'mr', 'zelensky', 'to', 'investigate', 'his', 'leading', 'democratic', 'political', 'rival', ',', 'joe', 'biden.the', 'impeachment', 'inquiry', 'stems', 'from', 'the', 'call', ',', 'which', 'was', 'flagged', 'up', 'by', 'a', 'whistleblower', 'in', 'august.the', 'whistleblower', 'alleged', 'that', 'mr', 'trump', 'used', 'a', '$', '400m', 'military', 'aid', 'package', 'to', 'ukraine', ',', 'which', '
# ...

# %%
stop_words = set(stopwords.words('english'))
corpus = [] 
for w in word_tokens:
    if w not in stop_words: 
        corpus.append(w) 

print(corpus)
# Out:
# ['share', 'withemailfacebookmessengermessengertwitterpinterestwhatsapplinkedincopy', 'linkthese', 'external', 'links', 'open', 'new', 'windowus', 'democratic', 'lawmakers', 'demanded', 'documents', 'white', 'house', 'part', 'impeachment', 'inquiry', 'president', 'donald', 'trump', '.', 'documents', 'relate', 'call', 'mr', 'trump', 'ukrainian', 'president', 'volodymyr', 'zelensky', '25', 'july', '.', 'call', ',', 'mr', 'trump', 'pushed', 'mr', 'zelensky', 'investigate', 'leading', 'democratic', 'political', 'rival', ',', 'joe', 'biden.the', 'impeachment', 'inquiry', 'stems', 'call', ',', 'flagged', 'whistleblower', 'august.the', 'whistleblower', 'alleged', 'mr', 'trump', 'used', '$', '400m', 'military', 'aid', 'package', 'ukraine', ',', 'suspended', 'earlier', 'july', ',', 'leverage', 'persuade', 'mr', 'zelensky', '.', 'white', 'house', 'released', 'aid', 'september.mr', 'trump', 'denied', 'wrongdoing', ',', 'accusing', 'political', 'opponents', '``', 'witch', 'hunt', "''", '.but', 'm
# ...

# %%
for i in range(len(corpus)):
    corpus [i] = corpus [i].lower()
    corpus [i] = re.sub(r'\W',' ',corpus [i])
    corpus [i] = re.sub(r'\s+',' ',corpus [i])
print(len(corpus))
# Out:
# 571

# %%
filtered_sentence = [] 
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 




print("\n\nFiltered Sentence \n\n")
print(" ".join(filtered_sentence))
# Out:
# Filtered Sentence
#
#
# ...

# %%
for i in range(len(corpus)):
    corpus [i] = corpus [i].lower()
    corpus [i] = re.sub(r'\W',' ',corpus [i])
    corpus [i] = re.sub(r'\s+',' ',corpus [i])
print(len(corpus))
# Out:
# 571

# %%
wordfreq = {}
for sentence in corpus:
    tokens = nltk.word_tokenize(sentence)
    for token in tokens:
        if token not in wordfreq.keys():
            wordfreq[token] = 1
        else:
            wordfreq[token] += 1

# %%
wordfreq
# Out:
# {'share': 1,
#  'withemailfacebookmessengermessengertwitterpinterestwhatsapplinkedincopy': 1,
#  'linkthese': 1,
#  'external': 1,
#  'links': 1,
#  'open': 1,
#  'new': 2,
#  'windowus': 1,
#  'democratic': 2,
#  'lawmakers': 1,
#  'demanded': 1,
#  'documents': 5,
#  'white': 5,
#  'house': 8,
#  'part': 1,
#  'impeachment': 2,
#  'inquiry': 5,
#  'president': 12,
#  'donald': 1,
#  'trump': 20,
#  'relate': 1,
#  'call': 6,
#  'mr': 23,
#  'ukrainian': 3,
#  'volodymyr': 1,
#  'zelensky': 4,
#  '25': 2,
#  'july': 3,
#  'pushed': 1,
#  'investigate': 3,
#  'leading': 2,
#  'political': 2,
#  'rival': 2,
#  'joe': 2,
#  'biden': 5,
#  'the': 2,
#  'stems': 1,
#  'flagged': 1,
#  'whistleblower': 5,
#  'august': 1,
#  'alleged': 1,
#  'used': 2,
#  '400m': 1,
#  'military': 1,
#  'aid': 2,
#  'package': 1,
#  'ukraine': 4,
#  'suspended': 1,
#  'earlier': 2,
#  'leverage': 1,
#  'persuade': 1,
#  'released': 3,
#  'september': 1,
#  'denied': 1,
#  'wrongdoing': 2,
# ...

# %%
import heapq
most_freq = heapq.nlargest(20, wordfreq, key=wordfreq.get)
most_freq
# Out:
# ['mr',
#  'trump',
#  'president',
#  's',
#  'house',
#  'democrats',
#  'call',
#  'senate',
#  'documents',
#  'white',
#  'inquiry',
#  'biden',
#  'whistleblower',
#  'us',
#  'official',
#  'zelensky',
#  'ukraine',
#  'committees',
#  'subpoena',
#  'would']
